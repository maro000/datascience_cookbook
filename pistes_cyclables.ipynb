# %% [markdown]
# <a href="https://colab.research.google.com/github/maro000/datascience_cookbook/blob/master/pistes_cyclables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url= ("https://raw.githubusercontent.com/"
      "ipython-books/cookbook-2nd-data/"
      "master/bikes.csv")

# %%
df = pd.read_csv(url,index_col='Date',
                 parse_dates=True, dayfirst=True)

# %%
df.head(2)
# Out:
#            Unnamed: 1  Berri1  CSC  ...  PierDup  Rachel1  Totem_Laurier
# Date                                ...
# 2013-01-01      00:00       0    0  ...        0        1              0
# 2013-01-02      00:00      69    0  ...        0        2              0
#
# [2 rows x 9 columns]

# %%
df.describe()
# Out:
#             Berri1          CSC  ...      Rachel1  Totem_Laurier
# count   261.000000   261.000000  ...   261.000000     261.000000
# mean   2743.390805  1221.858238  ...  3084.425287    1858.793103
# std    2247.957848  1070.037364  ...  2380.255540    1434.899574
# min       0.000000     0.000000  ...     0.000000       0.000000
# 25%     392.000000    12.000000  ...   451.000000     340.000000
# 50%    2771.000000  1184.000000  ...  3111.000000    2087.000000
# 75%    4767.000000  2168.000000  ...  5338.000000    3168.000000
# max    6803.000000  3330.000000  ...  8555.000000    4293.000000
#
# [8 rows x 8 columns]

# %%
df[['Berri1','PierDup']].plot(figsize=(10,6),style=['-','--'],lw=2)

# %%
df.index.weekday_name
Index(['Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','Monday',
       'Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','Monday','Tuesday','Wednesday'],
       dtype='object',name='Date',length=261)

# %%
df_week =df.groupby(df.index.weekday).sum()

# %%
df_week
# Out:
#       Berri1    CSC  Mais1   Mais2   Parc  PierDup  Rachel1  Totem_Laurier
# Date
# 0     106826  51646  68087  129982  69767    44500   119211          72883
# 1     117244  54656  76974  141217  74299    40679   123533          76559
# 2     120434  59604  79033  145860  80437    42564   125173          79501
# 3     115193  52340  76273  141424  73668    36349   120684          74540
# 4     105701  44252  71605  127526  64385    36850   118556          71426
# 5      75754  27226  45947   79743  35544    46149    97143          56438
# 6      74873  29181  40812   75746  37620    53812   100735          53798
